# %%
# import 
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
from pandas import DataFrame as df

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')
wiki = soup.find('table')

# %%
neigh = wiki.find_all('tr')
d = []
for neigh in neigh:
    cols=neigh.find_all('td')
    cols=[x.text.strip() for x in cols]
    d.append(cols)

# %%
columns=['PostalCode','Borough','Neighbourhood']
df_TO = pd.DataFrame(data=d,columns=columns)[1:]
print(df_TO.count())
df_TO.head()
# Out:
# PostalCode       288
# Borough          288
# Neighbourhood    288
# dtype: int64
#   PostalCode           Borough     Neighbourhood
# 1        M1A      Not assigned      Not assigned
# 2        M2A      Not assigned      Not assigned
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront

# %%
#Ignore cells with a borough that is Not assigned.
df_TO_clean =df_TO[df_TO['Borough'] !='Not assigned']

# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough
for index, row in df_TO_clean.iterrows():
    if row['Neighbourhood']=='Not assigned':
        row['Neighbourhood']=row['Borough']

# %%
df_TO_clean_gr = df_TO_clean.groupby(['PostalCode','Borough'], sort=False).agg( ','.join)
df_TO_clean_gr = df_TO_clean_gr.reset_index()
df_TO_clean_gr.head()
# Out:
#   PostalCode           Borough                    Neighbourhood
# 0        M3A        North York                        Parkwoods
# 1        M4A        North York                 Victoria Village
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park
# 3        M6A        North York  Lawrence Heights,Lawrence Manor
# 4        M7A      Queen's Park                     Queen's Park

# %%
df_TO_clean_gr.shape
df_TO_clean_gr['PostalCode'].head()
# Out:
# 0    M3A
# 1    M4A
# 2    M5A
# 3    M6A
# 4    M7A
# Name: PostalCode, dtype: object

# %%
pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\panda\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: future in c:\users\panda\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: requests in c:\users\panda\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: click in c:\users\panda\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: six in c:\users\panda\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: ratelim in c:\users\panda\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\panda\anaconda3\lib\site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\panda\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\panda\anaconda3\lib\site-packages (from requests->geocoder) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\panda\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: decorator in c:\users\panda\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geocoder
import numpy as np

# %%
# convert postal code to list to iterate
pc_list = df_TO_clean_gr['PostalCode'].tolist()

# %%
# create empty lists to store values
lat_vals=[]
lon_vals=[]

for pc in pc_list:
    lat_lng_coords=None
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(pc))
        lat_lng_coords = g.latlng

    lat_vals.append(lat_lng_coords[0])
    lon_vals.append(lat_lng_coords[1])
    
df_TO_clean_gr['Latitude'] = lat_vals
df_TO_clean_gr['Longitude'] = lon_vals

df_TO_clean_gr.head()
# Out:
#   PostalCode           Borough                    Neighbourhood   Latitude  \
# 0        M3A        North York                        Parkwoods  43.752420
# 1        M4A        North York                 Victoria Village  43.730600
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park  43.650295
# 3        M6A        North York  Lawrence Heights,Lawrence Manor  43.723270
# 4        M7A      Queen's Park                     Queen's Park  43.661150
#
#    Longitude
# 0 -79.329242
# 1 -79.313265
# 2 -79.359166
# 3 -79.451286
# 4 -79.391715

# %%
DTO_data = df_TO_clean_gr[df_TO_clean_gr['Borough'].str.contains("Toronto")].reset_index(drop=True)
DTO_data.head()
# Out:
#   PostalCode           Borough             Neighbourhood   Latitude  Longitude
# 0        M5A  Downtown Toronto  Harbourfront,Regent Park  43.650295 -79.359166
# 1        M5B  Downtown Toronto   Ryerson,Garden District  43.657363 -79.378180
# 2        M5C  Downtown Toronto            St. James Town  43.651210 -79.375481
# 3        M4E      East Toronto               The Beaches  43.676531 -79.295425
# 4        M5E  Downtown Toronto               Berczy Park  43.645160 -79.373675

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(DTO_data['Borough'].unique()),
        DTO_data.shape[0]
    )
)
# Out:
# The dataframe has 4 boroughs and 38 neighborhoods.

# %% [markdown]
# # Explore Neighborhoods in Toronto

# %% [markdown]
# ### Create a function to repeat the same process to all the neighborhoods in Toronto

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\panda\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: numpy in c:\users\panda\anaconda3\lib\site-packages (from folium) (1.16.4)
# Requirement already satisfied: jinja2>=2.9 in c:\users\panda\anaconda3\lib\site-packages (from folium) (2.10.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\panda\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: requests in c:\users\panda\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\panda\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\users\panda\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\panda\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\panda\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\panda\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\panda\anaconda3\lib\site-packages (from requests->folium) (2019.6.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from geopy.geocoders import Nominatim

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(DTO_data['Latitude'], DTO_data['Longitude'], DTO_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'U1FGIWTI0KHEV5JJL5ZUSMVFHG2C413OXBS210OIFVX4LUNO' # your Foursquare ID
CLIENT_SECRET = 'A0EP5GWESZAYDUXGDBPFMLT5DDCJ3P1D2EOP3QRFISGGW040' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: U1FGIWTI0KHEV5JJL5ZUSMVFHG2C413OXBS210OIFVX4LUNO
# CLIENT_SECRET:A0EP5GWESZAYDUXGDBPFMLT5DDCJ3P1D2EOP3QRFISGGW040

# %%
import urllib
def getNearbyVenues(names, latitudes, longitudes, radius=5000, categoryIds=''):
    try:
        venues_list=[]
        for name, lat, lng in zip(names, latitudes, longitudes):
            #print(name)

            # create the API request URL
            url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)

            if (categoryIds != ''):
                url = url + '&categoryId={}'
                url = url.format(categoryIds)

            # make the GET request
            response = requests.get(url).json()
            results = response["response"]['venues']

            # return only relevant information for each nearby venue
            for v in results:
                success = False
                try:
                    category = v['categories'][0]['name']
                    success = True
                except:
                    pass

                if success:
                    venues_list.append([(
                        name, 
                        lat, 
                        lng, 
                        v['name'], 
                        v['location']['lat'], 
                        v['location']['lng'],
                        v['categories'][0]['name']
                    )])

        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns = ['Localidad', 
                  'Localidad Latitude', 
                  'Localidad Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    except:
        print(url)
        print(response)
        print(results)
        print(nearby_venues)

    return(nearby_venues)

# %%
LIMIT = 500 
radius = 5000

# %%
#https://developer.foursquare.com/docs/resources/categories
#preschool =52e81612bcbc57f1066b7a45

preschool  = getNearbyVenues(names=DTO_data['Neighbourhood'], latitudes=DTO_data['Latitude'], longitudes=DTO_data['Longitude'], radius=5000, categoryIds='52e81612bcbc57f1066b7a45')
preschool.head()
# Out:
#                   Localidad  Localidad Latitude  Localidad Longitude  \
# 0  Harbourfront,Regent Park           43.650295           -79.359166
# 1  Harbourfront,Regent Park           43.650295           -79.359166
# 2   Ryerson,Garden District           43.657363           -79.378180
# 3   Ryerson,Garden District           43.657363           -79.378180
# 4            St. James Town           43.651210           -79.375481
#
#                 Venue  Venue Latitude  Venue Longitude Venue Category
# 0     The Wright Spot       43.672679       -79.319917      Preschool
# 1  Creative Preschool       43.679454       -79.336772      Preschool
# 2     The Wright Spot       43.672679       -79.319917      Preschool
# 3  Creative Preschool       43.679454       -79.336772      Preschool
# 4     The Wright Spot       43.672679       -79.319917      Preschool

# %%
preschool.shape
# Out:
# (39, 7)

# %%
#https://developer.foursquare.com/docs/resources/categories
#elementary =4f4533804b9074f6e4fb0105

elementary = getNearbyVenues(names=DTO_data['Neighbourhood'], latitudes=DTO_data['Latitude'], longitudes=DTO_data['Longitude'], radius=5000, categoryIds='4f4533804b9074f6e4fb0105')
elementary.head()
# Out:
#                   Localidad  Localidad Latitude  Localidad Longitude  \
# 0  Harbourfront,Regent Park           43.650295           -79.359166
# 1  Harbourfront,Regent Park           43.650295           -79.359166
# 2  Harbourfront,Regent Park           43.650295           -79.359166
# 3  Harbourfront,Regent Park           43.650295           -79.359166
# 4  Harbourfront,Regent Park           43.650295           -79.359166
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0      Market Lane Public School       43.653344       -79.364758
# 1  Ecole Elementaire La Mosaique       43.687073       -79.330219
# 2   Nelson Mandela Public School       43.658111       -79.360072
# 3   Lord Lansdowne Public School       43.658731       -79.402031
# 4  Givins Shaw Elementary School       43.646395       -79.418096
#
#       Venue Category
# 0  Elementary School
# 1  Elementary School
# 2  Elementary School
# 3  Elementary School
# 4  Elementary School

# %%
#https://developer.foursquare.com/docs/resources/categories
#industry  =56aa371be4b08b9a8d5734d7

industry = getNearbyVenues(names=DTO_data['Neighbourhood'], latitudes=DTO_data['Latitude'], longitudes=DTO_data['Longitude'], radius=5000, categoryIds='56aa371be4b08b9a8d5734d7')
industry
# Out:
#                                             Localidad  Localidad Latitude  \
# 0                            Harbourfront,Regent Park           43.650295
# 1                             Ryerson,Garden District           43.657363
# 2                                      St. James Town           43.651210
# 3                                         Berczy Park           43.645160
# 4                                  Central Bay Street           43.656091
# 5                                            Christie           43.668781
# 6                              Adelaide,King,Richmond           43.649700
# 7                         Dovercourt Village,Dufferin           43.665087
# 8     Harbourfront East,Toronto Islands,Union Station           43.630210
# 9                             Little Portugal,Trinity           43.648525
# 10            Design Exchange,Toronto Dominion Centre           43.647100
# 11         Brockton,Exhibition Place,Parkdale Village           43.639410
# 12                      Commerce Court,Victoria Hotel           43.648395
# 13                       High Park,The Junction South           43.659935
# 14                  The Annex,North Midtown,Yorkville           43.674840
# 15                              Parkdale,Roncesvalles           43.647870
# 16                      Harbord,University of Toronto           43.663110
# 17                                  Runnymede,Swansea           43.649620
# 18                                  Runnymede,Swansea           43.649620
# 19            Chinatown,Grange Park,Kensington Market           43.653530
# 20  Deer Park,Forest Hill SE,Rathnelly,South Hill,...           43.686074
# 21  CN Tower,Bathurst Quay,Island airport,Harbourf...           43.640815
# 22                    Stn A PO Boxes 25 The Esplanade           43.648690
# 23                         Cabbagetown,St. James Town           43.668160
# 24              First Canadian Place,Underground city           43.648280
# 25                               Church and Wellesley           43.666585
# 26  Business Reply Mail Processing Centre 969 Eastern           43.648690
#
#     Localidad Longitude                 Venue  Venue Latitude  \
# 0            -79.359166             Salt Dome       43.640874
# 1            -79.378180             Salt Dome       43.640874
# 2            -79.375481             Salt Dome       43.640874
# 3            -79.373675             Salt Dome       43.640874
# 4            -79.384930             Salt Dome       43.640874
# 5            -79.420710             Salt Dome       43.640874
# 6            -79.382582             Salt Dome       43.640874
# 7            -79.438705             Salt Dome       43.640874
# 8            -79.362433             Salt Dome       43.640874
# 9            -79.417757             Salt Dome       43.640874
# 10           -79.381531             Salt Dome       43.640874
# 11           -79.424362             Salt Dome       43.640874
# 12           -79.378865             Salt Dome       43.640874
# 13           -79.463019             Salt Dome       43.640874
# 14           -79.403768             Salt Dome       43.640874
# 15           -79.449776             Salt Dome       43.640874
# 16           -79.401801             Salt Dome       43.640874
# 17           -79.476141             Salt Dome       43.640874
# 18           -79.476141  Lipson Shirt Factory       43.633548
# 19           -79.397233             Salt Dome       43.640874
# 20           -79.402265             Salt Dome       43.640874
# 21           -79.399538             Salt Dome       43.640874
# 22           -79.385440             Salt Dome       43.640874
# 23           -79.366602             Salt Dome       43.640874
# 24           -79.381461             Salt Dome       43.640874
# 25           -79.381302             Salt Dome       43.640874
# 26           -79.385440             Salt Dome       43.640874
#
#     Venue Longitude     Venue Category
# 0        -79.408053  Industrial Estate
# 1        -79.408053  Industrial Estate
# 2        -79.408053  Industrial Estate
# 3        -79.408053  Industrial Estate
# 4        -79.408053  Industrial Estate
# 5        -79.408053  Industrial Estate
# 6        -79.408053  Industrial Estate
# 7        -79.408053  Industrial Estate
# 8        -79.408053  Industrial Estate
# 9        -79.408053  Industrial Estate
# 10       -79.408053  Industrial Estate
# 11       -79.408053  Industrial Estate
# 12       -79.408053  Industrial Estate
# 13       -79.408053  Industrial Estate
# 14       -79.408053  Industrial Estate
# 15       -79.408053  Industrial Estate
# 16       -79.408053  Industrial Estate
# 17       -79.408053  Industrial Estate
# 18       -79.524703  Industrial Estate
# 19       -79.408053  Industrial Estate
# 20       -79.408053  Industrial Estate
# 21       -79.408053  Industrial Estate
# 22       -79.408053  Industrial Estate
# 23       -79.408053  Industrial Estate
# 24       -79.408053  Industrial Estate
# 25       -79.408053  Industrial Estate
# 26       -79.408053  Industrial Estate

# %%
#https://developer.foursquare.com/docs/resources/categories
#gas  =56aa371be4b08b9a8d5734d7

gas = getNearbyVenues(names=DTO_data['Neighbourhood'], latitudes=DTO_data['Latitude'], longitudes=DTO_data['Longitude'], radius=1000, categoryIds='4bf58dd8d48988d113951735')
gas.head()
print(gas.shape)
# Out:
# (211, 7)

# %%
def addToMap(df, color, existingMap):
    for lat, lng, local, venue, venueCat in zip(df['Venue Latitude'], df['Venue Longitude'], df['Localidad'], df['Venue'], df['Venue Category']):
        label = '{} ({}) - {}'.format(venue, venueCat, local)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7).add_to(existingMap)

# %%
map_preschool = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(preschool, 'red', map_preschool)
map_preschool
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_industry = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(industry, 'gold', map_industry)
map_industry
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_gas = folium.Map(location=[latitude, longitude], zoom_start=12)
addToMap(gas, 'green', map_gas)
map_gas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def addColumn(startDf, columnTitle, dataDf):
    grouped = dataDf.groupby('Localidad').count()
    
    for n in startDf['Localidad']:
        try:
            startDf.loc[startDf['Localidad'] == n,columnTitle] = grouped.loc[n, 'Venue']
        except:
            startDf.loc[startDf['Localidad'] == n,columnTitle] = 0

# %%
df_data =DTO_data.copy()
df_data.rename(columns={'Neighbourhood':'Localidad'}, inplace=True)
addColumn(df_data, 'preschool', preschool)
addColumn(df_data, 'elementary', elementary)
addColumn(df_data, 'industry', industry)
addColumn(df_data, 'gas', gas)
df_data
# Out:
#    PostalCode           Borough  \
# 0         M5A  Downtown Toronto
# 1         M5B  Downtown Toronto
# 2         M5C  Downtown Toronto
# 3         M4E      East Toronto
# 4         M5E  Downtown Toronto
# 5         M5G  Downtown Toronto
# 6         M6G  Downtown Toronto
# 7         M5H  Downtown Toronto
# 8         M6H      West Toronto
# 9         M5J  Downtown Toronto
# 10        M6J      West Toronto
# 11        M4K      East Toronto
# 12        M5K  Downtown Toronto
# 13        M6K      West Toronto
# 14        M4L      East Toronto
# 15        M5L  Downtown Toronto
# 16        M4M      East Toronto
# 17        M4N   Central Toronto
# 18        M5N   Central Toronto
# 19        M4P   Central Toronto
# 20        M5P   Central Toronto
# 21        M6P      West Toronto
# 22        M4R   Central Toronto
# 23        M5R   Central Toronto
# 24        M6R      West Toronto
# 25        M4S   Central Toronto
# 26        M5S  Downtown Toronto
# 27        M6S      West Toronto
# 28        M4T   Central Toronto
# 29        M5T  Downtown Toronto
# 30        M4V   Central Toronto
# 31        M5V  Downtown Toronto
# 32        M4W  Downtown Toronto
# 33        M5W  Downtown Toronto
# 34        M4X  Downtown Toronto
# 35        M5X  Downtown Toronto
# 36        M4Y  Downtown Toronto
# 37        M7Y      East Toronto
#
#                                             Localidad   Latitude  Longitude  \
# 0                            Harbourfront,Regent Park  43.650295 -79.359166
# 1                             Ryerson,Garden District  43.657363 -79.378180
# 2                                      St. James Town  43.651210 -79.375481
# 3                                         The Beaches  43.676531 -79.295425
# 4                                         Berczy Park  43.645160 -79.373675
# 5                                  Central Bay Street  43.656091 -79.384930
# 6                                            Christie  43.668781 -79.420710
# 7                              Adelaide,King,Richmond  43.649700 -79.382582
# 8                         Dovercourt Village,Dufferin  43.665087 -79.438705
# 9     Harbourfront East,Toronto Islands,Union Station  43.630210 -79.362433
# 10                            Little Portugal,Trinity  43.648525 -79.417757
# 11                        The Danforth West,Riverdale  43.683178 -79.355105
# 12            Design Exchange,Toronto Dominion Centre  43.647100 -79.381531
# 13         Brockton,Exhibition Place,Parkdale Village  43.639410 -79.424362
# 14                      The Beaches West,India Bazaar  43.667965 -79.314667
# 15                      Commerce Court,Victoria Hotel  43.648395 -79.378865
# 16                                    Studio District  43.660629 -79.334855
# 17                                      Lawrence Park  43.728420 -79.387133
# 18                                           Roselawn  43.711941 -79.419120
# 19                                   Davisville North  43.712755 -79.388514
# 20                 Forest Hill North,Forest Hill West  43.694785 -79.414405
# 21                       High Park,The Junction South  43.659935 -79.463019
# 22                                 North Toronto West  43.714523 -79.406960
# 23                  The Annex,North Midtown,Yorkville  43.674840 -79.403768
# 24                              Parkdale,Roncesvalles  43.647870 -79.449776
# 25                                         Davisville  43.703395 -79.385964
# 26                      Harbord,University of Toronto  43.663110 -79.401801
# 27                                  Runnymede,Swansea  43.649620 -79.476141
# 28                         Moore Park,Summerhill East  43.690685 -79.382946
# 29            Chinatown,Grange Park,Kensington Market  43.653530 -79.397233
# 30  Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686074 -79.402265
# 31  CN Tower,Bathurst Quay,Island airport,Harbourf...  43.640815 -79.399538
# 32                                           Rosedale  43.682205 -79.377945
# 33                    Stn A PO Boxes 25 The Esplanade  43.648690 -79.385440
# 34                         Cabbagetown,St. James Town  43.668160 -79.366602
# 35              First Canadian Place,Underground city  43.648280 -79.381461
# 36                               Church and Wellesley  43.666585 -79.381302
# 37  Business Reply Mail Processing Centre 969 Eastern  43.648690 -79.385440
#
#     preschool  elementary  industry   gas
# 0         2.0        34.0       1.0   6.0
# 1         2.0        44.0       1.0  11.0
# 2         2.0        38.0       1.0  10.0
# 3         2.0        23.0       0.0   7.0
# 4         1.0        31.0       1.0   6.0
# 5         2.0        43.0       1.0   7.0
# 6         0.0        49.0       1.0   6.0
# 7         1.0        32.0       1.0   8.0
# 8         0.0        47.0       1.0   7.0
# 9         0.0        19.0       1.0   1.0
# 10        0.0        41.0       1.0   5.0
# 11        2.0        45.0       0.0   5.0
# 12        1.0        32.0       1.0   8.0
# 13        0.0        37.0       1.0   1.0
# 14        2.0        28.0       0.0   4.0
# 15        1.0        32.0       1.0   8.0
# 16        2.0        34.0       0.0  10.0
# 17        0.0        42.0       0.0   0.0
# 18        0.0        42.0       0.0   2.0
# 19        1.0        43.0       0.0   4.0
# 20        1.0        47.0       0.0   5.0
# 21        0.0        40.0       1.0  10.0
# 22        0.0        40.0       0.0   2.0
# 23        1.0        48.0       1.0   5.0
# 24        0.0        39.0       1.0   6.0
# 25        2.0        45.0       0.0   6.0
# 26        1.0        48.0       1.0   4.0
# 27        0.0        36.0       2.0   3.0
# 28        2.0        47.0       0.0   2.0
# 29        1.0        44.0       1.0   7.0
# 30        1.0        47.0       1.0   4.0
# 31        0.0        29.0       1.0   7.0
# 32        2.0        47.0       0.0   3.0
# 33        1.0        32.0       1.0   7.0
# 34        2.0        43.0       1.0   3.0
# 35        1.0        32.0       1.0   8.0
# 36        2.0        48.0       1.0   6.0
# 37        1.0        32.0       1.0   7.0

# %% [markdown]
# ### Applying Weights

# %%
# positive weight
weight_elementary = 5

# negative weight
weight_preschool = -10
weight_industry = -5
weight_gas = -5

# %%
df_weighted = df_data[['Localidad']].copy()

# %%
df_weighted['Score'] = df_data['elementary'] * weight_elementary + df_data['preschool'] * weight_preschool + df_data['industry'] *weight_industry + df_data['gas'] * weight_gas
df_weighted = df_weighted.sort_values(by=['Score'], ascending=False)
df_weighted
# Out:
#                                             Localidad  Score
# 17                                      Lawrence Park  210.0
# 6                                            Christie  210.0
# 28                         Moore Park,Summerhill East  205.0
# 26                      Harbord,University of Toronto  205.0
# 30  Deer Park,Forest Hill SE,Rathnelly,South Hill,...  200.0
# 20                 Forest Hill North,Forest Hill West  200.0
# 18                                           Roselawn  200.0
# 23                  The Annex,North Midtown,Yorkville  200.0
# 32                                           Rosedale  200.0
# 8                         Dovercourt Village,Dufferin  195.0
# 22                                 North Toronto West  190.0
# 36                               Church and Wellesley  185.0
# 19                                   Davisville North  185.0
# 11                        The Danforth West,Riverdale  180.0
# 10                            Little Portugal,Trinity  175.0
# 13         Brockton,Exhibition Place,Parkdale Village  175.0
# 25                                         Davisville  175.0
# 34                         Cabbagetown,St. James Town  175.0
# 29            Chinatown,Grange Park,Kensington Market  170.0
# 24                              Parkdale,Roncesvalles  160.0
# 27                                  Runnymede,Swansea  155.0
# 5                                  Central Bay Street  155.0
# 21                       High Park,The Junction South  145.0
# 1                             Ryerson,Garden District  140.0
# 0                            Harbourfront,Regent Park  115.0
# 2                                      St. James Town  115.0
# 4                                         Berczy Park  110.0
# 33                    Stn A PO Boxes 25 The Esplanade  110.0
# 37  Business Reply Mail Processing Centre 969 Eastern  110.0
# 15                      Commerce Court,Victoria Hotel  105.0
# 12            Design Exchange,Toronto Dominion Centre  105.0
# 7                              Adelaide,King,Richmond  105.0
# 31  CN Tower,Bathurst Quay,Island airport,Harbourf...  105.0
# 35              First Canadian Place,Underground city  105.0
# 16                                    Studio District  100.0
# 14                      The Beaches West,India Bazaar  100.0
# 9     Harbourfront East,Toronto Islands,Union Station   85.0
# 3                                         The Beaches   60.0
